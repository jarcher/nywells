# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
date_spec = {'nominal': [1, 2], 'actual': [1, 3]}

# %%
df = pd.read_csv('/Users/jraMBP/archerplay/og.csv', parse_dates=date_spec,index_col=0) #index is the nominal column

# %%
# %pwd
# Out:
# '/Users/jraMBP'

# %%
print(df.shape)
# Out:
# (30053, 18)

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df.columns)
# Out:
# Index(['actual', 'Production Year', 'Town', 'Field', 'Producing Formation',
#        'Active Oil Wells', 'Inactive Oil Wells', 'Active Gas Wells',
#        'Inactive Gas Wells', 'Injection Wells', 'Disposal Wells',
#        'Self-use Well', 'Oil Produced, bbl', 'Gas Produced, Mcf',
#        'Water produced, bbl', 'Taxable Gas, Mcf', 'Purchaser Codes',
#        'Location'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# actual                 object
# Production Year         int64
# Town                   object
# Field                  object
# Producing Formation    object
# Active Oil Wells        int64
# Inactive Oil Wells      int64
# Active Gas Wells        int64
# Inactive Gas Wells      int64
# Injection Wells         int64
# Disposal Wells          int64
# Self-use Well          object
# Oil Produced, bbl       int64
# Gas Produced, Mcf       int64
# Water produced, bbl     int64
# Taxable Gas, Mcf        int64
# Purchaser Codes        object
# Location               object
# dtype: object

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of                                                                     actual  \
# nominal
# 12/03/1996 Buffalo China, Inc.                             12/03/1996 Erie
# 03/29/1996 Copper Ridge Oil, Inc.                       03/29/1996 Steuben
# 02/14/1995 White, Walter W. & Christina L.          02/14/1995 Cattaraugus
# 01/19/1995 Stiegler, Richard M                             01/19/1995 Erie
# 02/12/1996 Bucher, Charles J                        02/12/1996 Cattaraugus
# 04/02/1996 Cotton Well Drilling Company,  Inc.       04/02/1996 Chautauqua
# 04/05/1995 Oil, Gas & Land Services, Inc.            04/05/1995 Chautauqua
# 03/15/1995 Traxler, Joyce                               03/15/1995 Genesee
# 09/12/1996 Cunningham Natural Gas Corp.                09/12/1996 Allegany
# 10/18/1996 Crowell, Walter R.                        10/18/1996 Chautauqua
# 04/04/1996 Belden & Blake Corporation                04/04/1996 Chautauqua
# ...
